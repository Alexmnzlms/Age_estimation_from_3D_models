# %%
import enum
from random import random
from re import S
from xml.etree.ElementInclude import include
from sklearn import metrics
import tensorflow as tf
from tensorflow.keras import callbacks, Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ReLU, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Lambda, ZeroPadding2D, concatenate, Average
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError, CategoricalCrossentropy
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import VGG16

from sklearn.model_selection import KFold

from keras.utils.vis_utils import plot_model

from collections import Counter

import scipy.ndimage as sci

import numpy as np
from sklearn.metrics import *
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import os
import cv2 as cv

import random

import ranges_of_age as roa

import sys

from datetime import datetime

import functions as fn

# %% [markdown]
# # Instrucciones de USO
#
# El notebook esa controlado por 3 variables principales:
# - **COLORMODE**: ["rgb"/"grayscale"] controla si utiliza la representación RGB o la representación en escala de grises (SDM, NDM y GNDM por separado)
# - **RESNET**: controla si utiliza la red RESNET-CNN (solo con rgb) o la red PANORAMA-CNN
# - **MODEL**: carga el modelo entrenado. Los modelos tiene todos la nomenclatura DDHHMM. Se nombran en función del día DD, hora HH y minuto MM en el que comenzó el entrenamiento. Por defecto se carga el 221512. Los modelos entrenados estan en la carpeta execution.

# %%
COLORMODE = "rgb"
RESNET = True
MODEL = 221512

# %%
VERBOSE = 2
mse = []
r2 = []
rmse = []
mae = []

IMG_SHAPE = (36,108)
depth = 3
if RESNET:
    cnn = fn.create_CNN_Resnet
    model_weights = '../paper_execution/ngpu/results/model_rgb_resnet/model_rgb_resnet'
    # model_weights = '../execution/'+str(MODEL)+'/model_rgb_resnet/model_rgb_resnet'
else:
    cnn = fn.create_CNN
    model_weights = '../execution/'+str(MODEL)+'/model_rgb_panoramacnn/model_rgb_panoramacnn'

# %%
cnn_0 = cnn(0,IMG_SHAPE[0],IMG_SHAPE[1],depth)
cnn_1 = cnn(1,IMG_SHAPE[0],IMG_SHAPE[1],depth)
cnn_2 = cnn(2,IMG_SHAPE[0],IMG_SHAPE[1],depth)

# %% [markdown]
# # Eliminar la ultima capa
#
# La siguiente celda junta el output de las 3 redes en una capa Average de Keras.

# %%
x = Average()([cnn_0.output, cnn_1.output, cnn_2.output])

# %%
model = Model(inputs=[cnn_0.input, cnn_1.input, cnn_2.input], outputs=x)

optimizer = Adam()

model.compile(loss=MeanAbsoluteError(), optimizer=optimizer, metrics=['mae'])
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 108, 36, 3)  0           []
#                                 ]
#
#  input_11 (InputLayer)          [(None, 108, 36, 3)  0           []
#                                 ]
#
#  input_12 (InputLayer)          [(None, 108, 36, 3)  0           []
#                                 ]
#
#  resnet50_0 (Functional)        (None, 4, 2, 2048)   23587712    ['input_10[0][0]']
#
#  resnet50_1 (Functional)        (None, 4, 2, 2048)   23587712    ['input_11[0][0]']
#
#  resnet50_2 (Functional)        (None, 4, 2, 2048)   23587712    ['input_12[0][0]']
#
#  flatten_9 (Flatten)            (None, 16384)        0           ['resnet50_0[0][0]']
#
#  flatten_10 (Flatten)           (None, 16384)        0           ['resnet50_1[0][0]']
#
#  flatten_11 (Flatten)           (None, 16384)        0           ['resnet50_2[0][0]']
#  dense_27 (Dense)               (None, 100)          1638500     ['flatten_9[0][0]']
#
#  dense_30 (Dense)               (None, 100)          1638500     ['flatten_10[0][0]']
#
#  dense_33 (Dense)               (None, 100)          1638500     ['flatten_11[0][0]']
#
#  dense_28 (Dense)               (None, 100)          10100       ['dense_27[0][0]']
#
#  dense_31 (Dense)               (None, 100)          10100       ['dense_30[0][0]']
#
#  dense_34 (Dense)               (None, 100)          10100       ['dense_33[0][0]']
#
#  dropout_9 (Dropout)            (None, 100)          0           ['dense_28[0][0]']
#
#  dropout_10 (Dropout)           (None, 100)          0           ['dense_31[0][0]']
#
#  dropout_11 (Dropout)           (None, 100)          0           ['dense_34[0][0]']
#
#  dense_29 (Dense)               (None, 1)            101         ['dropout_9[0][0]']
#
#  dense_32 (Dense)               (None, 1)            101         ['dropout_10[0][0]']
#
#  dense_35 (Dense)               (None, 1)            101         ['dropout_11[0][0]']
#
#  average_3 (Average)            (None, 1)            0           ['dense_29[0][0]',
#                                                                   'dense_32[0][0]',
#                                                                   'dense_35[0][0]']
#
# ==================================================================================================
# Total params: 75,709,239
# Trainable params: 4,946,103
# Non-trainable params: 70,763,136
# __________________________________________________________________________________________________

# %%
tf_version = tf.__version__
if tf_version != "2.9.0":
    print("Error: Tensorflow version must be 2.9.0 and current version is {}".format(tf_version),file=sys.stderr)
    exit(1)

model.load_weights(model_weights)

# %%
name = "280_Izq/280_Izq_0"
test = [[name+'_panorama_ext_X.png',name+'_panorama_ext_Y.png',name+'_panorama_ext_Z.png',0]]
datagen = ImageDataGenerator()
datagen_test = fn.image_generator(test, "../pubis_data_proc_25_panorama_norm/", 1, datagen, IMG_SHAPE, colormode=COLORMODE, shuffle=False, weights=False)

estimation = model.predict(datagen_test, verbose=VERBOSE, steps=len(test))
est = estimation.flatten()
print("Age estimation: {}".format(est[0]))
# Out:
# 1/1 - 0s - 36ms/epoch - 36ms/step
# Age estimation: 52.29264450073242
